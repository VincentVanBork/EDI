# %%
import pandas as pd
#read the file
print("Hello")
df = pd.read_csv("./data.csv", index_col="index")
print(df.head())
# Out:
# Hello
#               host       time method                           url  response  \
# index
# 0      ***.novo.dk  805465029    GET                     /ksc.html       200
# 1      ***.novo.dk  805465031    GET    /images/ksclogo-medium.gif       200
# 2      ***.novo.dk  805465051    GET  /images/MOSAIC-logosmall.gif       200
# 3      ***.novo.dk  805465053    GET     /images/USA-logosmall.gif       200
# 4      ***.novo.dk  805465054    GET    /images/NASA-logosmall.gif       200
#
#        bytes
# index
# 0       7067
# 1       5866
# 2        363
# 3        234
# 4        786

# %%
# removing all not needed GET requests
remove_media = df[
    df.url.str.contains(".html", case=False) & df.url.str.contains(".htm", case=False)
    | df.url.str.endswith("/")
]

# %%
#grouping by host (client user)
grouped_by_host = remove_media.groupby(by=["host"])
print(len(grouped_by_host))
# more_than_one_site = grouped_by_host.filter(lambda x: len(x) == 1)
#removing session with only one action
more_than_one_site = grouped_by_host.filter(lambda x: len(x) > 1)
print(len(more_than_one_site.groupby(by=["host"])))
# Out:
# 33805
# 21656

# %%
grouped_more_action = more_than_one_site.groupby(by=["host"])
# print(len(grouped_more_action.groups))
# grouped_more_action.head()
divided_by_diff = grouped_more_action["time"].transform(lambda x: x.diff(), ).fillna(0)
more_than_one_site["difference"] = divided_by_diff

# %%
grouped_with_diff = more_than_one_site.groupby(by=["host"])
more_than_one_site["average"] = grouped_with_diff["difference"].transform(lambda x: (x.expanding().mean() ))
more_than_one_site.head(15)
# Out:
#                  host       time method  \
# index
# 0         ***.novo.dk  805465029    GET
# 6         ***.novo.dk  805465068    GET
# 12        ***.novo.dk  805465381    GET
# 13        ***.novo.dk  807951768    GET
# 18        ***.novo.dk  807951832    GET
# 23        ***.novo.dk  807951938    GET
# 26        ***.novo.dk  807952060    GET
# 37     007.thegap.com  805065755    GET
# 41     007.thegap.com  805065868    GET
# 44     007.thegap.com  805066115    GET
# 46     007.thegap.com  805066664    GET
# 48     007.thegap.com  805072924    GET
# 52     007.thegap.com  805073006    GET
# 55     007.thegap.com  805337998    GET
# 58     007.thegap.com  805338010    GET
#
#                                                 url  response  bytes  \
# index
# 0                                         /ksc.html       200   7067
# 6                   /shuttle/missions/missions.html       200   8678
# 12        /shuttle/resources/orbiters/columbia.html       200   6922
# 13     /shuttle/missions/sts-69/mission-sts-69.html       200  11264
# 18                              /shuttle/countdown/       200   4673
# 23                  /shuttle/countdown/liftoff.html       200   4665
# 26                   /shuttle/countdown/lps/fr.html       200   1879
# 37                              /shuttle/countdown/       200   3998
# 41     /shuttle/missions/sts-71/mission-sts-71.html       200  12722
# 44     /shuttle/missions/sts-71/mission-sts-71.html       200  12722
# 46      /shuttle/missions/sts-71/images/images.html       200   7634
# 48                              /shuttle/countdown/       200   3998
# 52                     /shuttle/countdown/tour.html       200   4347
# 55                                        /shuttle/       200    957
# 58                               /shuttle/missions/       200  12283
#
#        difference        average
# index
# 0             0.0       0.000000
# 6            39.0      19.500000
# 12          313.0     117.333333
# 13      2486387.0  621684.750000
# 18           64.0  497360.600000
# 23          106.0  414484.833333
# 26          122.0  355290.142857
# 37            0.0       0.000000
# 41          113.0      56.500000
# 44          247.0     120.000000
# 46          549.0     227.250000
# 48         6260.0    1433.800000
# 52           82.0    1208.500000
# 55       264992.0   38891.857143
# 58           12.0   34031.875000

# %%
grouped_with_diff = more_than_one_site.groupby(by=["host"])
more_than_one_site["session_change"] = [
    True if diff > avg else False
    for diff, avg in zip(
        more_than_one_site["difference"], more_than_one_site["average"]
    )
]

more_than_one_site["session_typical_change"] = [
    True if diff > 300 else False for diff in more_than_one_site["difference"]
]

more_than_one_site.head(25)
# Out:
#                                   host       time method  \
# index
# 0                          ***.novo.dk  805465029    GET
# 6                          ***.novo.dk  805465068    GET
# 12                         ***.novo.dk  805465381    GET
# 13                         ***.novo.dk  807951768    GET
# 18                         ***.novo.dk  807951832    GET
# 23                         ***.novo.dk  807951938    GET
# 26                         ***.novo.dk  807952060    GET
# 37                      007.thegap.com  805065755    GET
# 41                      007.thegap.com  805065868    GET
# 44                      007.thegap.com  805066115    GET
# 46                      007.thegap.com  805066664    GET
# 48                      007.thegap.com  805072924    GET
# 52                      007.thegap.com  805073006    GET
# 55                      007.thegap.com  805337998    GET
# 58                      007.thegap.com  805338010    GET
# 61                      007.thegap.com  805338117    GET
# 63                      007.thegap.com  806532047    GET
# 67                      007.thegap.com  807996988    GET
# 71     01-dynamic-c.wokingham.luna.net  804944219    GET
# 74     01-dynamic-c.wokingham.luna.net  805378659    GET
# 80     01-dynamic-c.wokingham.luna.net  805378707    GET
# 83     01-dynamic-c.wokingham.luna.net  805378737    GET
# 85     01-dynamic-c.wokingham.luna.net  805541614    GET
# 90     01-dynamic-c.wokingham.luna.net  806878944    GET
# 96     01-dynamic-c.wokingham.luna.net  806878955    GET
#
#                                                 url  response  bytes  \
# index
# 0                                         /ksc.html       200   7067
# 6                   /shuttle/missions/missions.html       200   8678
# 12        /shuttle/resources/orbiters/columbia.html       200   6922
# 13     /shuttle/missions/sts-69/mission-sts-69.html       200  11264
# 18                              /shuttle/countdown/       200   4673
# 23                  /shuttle/countdown/liftoff.html       200   4665
# 26                   /shuttle/countdown/lps/fr.html       200   1879
# 37                              /shuttle/countdown/       200   3998
# 41     /shuttle/missions/sts-71/mission-sts-71.html       200  12722
# 44     /shuttle/missions/sts-71/mission-sts-71.html       200  12722
# 46      /shuttle/missions/sts-71/images/images.html       200   7634
# 48                              /shuttle/countdown/       200   3998
# 52                     /shuttle/countdown/tour.html       200   4347
# 55                                        /shuttle/       200    957
# 58                               /shuttle/missions/       200  12283
# 61                                                /       200   7067
# 63                              /shuttle/countdown/       200   4324
# 67                              /shuttle/countdown/       200   4673
# 71      /shuttle/missions/sts-71/movies/movies.html       200   3089
# 74                                                /       200   7067
# 80                            /history/history.html       200   1602
# 83                  /shuttle/missions/missions.html       200   8678
# 85     /shuttle/missions/sts-71/mission-sts-71.html       200  13374
# 90                                        /ksc.html       200   7280
# 96                              /shuttle/countdown/       304      0
#
#        difference        average  session_change  session_typical_change
# index
# 0             0.0       0.000000           False                   False
# 6            39.0      19.500000            True                   False
# 12          313.0     117.333333            True                    True
# 13      2486387.0  621684.750000            True                    True
# 18           64.0  497360.600000           False                   False
# 23          106.0  414484.833333           False                   False
# 26          122.0  355290.142857           False                   False
# 37            0.0       0.000000           False                   False
# 41          113.0      56.500000            True                   False
# 44          247.0     120.000000            True                   False
# 46          549.0     227.250000            True                    True
# 48         6260.0    1433.800000            True                    True
# 52           82.0    1208.500000           False                   False
# 55       264992.0   38891.857143            True                    True
# 58           12.0   34031.875000           False                   False
# 61          107.0   30262.444444           False                   False
# 63      1193930.0  146629.200000            True                    True
# 67      1464941.0  266475.727273            True                    True
# 71            0.0       0.000000           False                   False
# 74       434440.0  217220.000000            True                    True
# 80           48.0  144829.333333           False                   False
# 83           30.0  108629.500000           False                   False
# 85       162877.0  119479.000000            True                    True
# 90      1337330.0  322454.166667            True                    True
# 96           11.0  276390.857143           False                   False

# %%
from skmultiflow.drift_detection import PageHinkley, HDDM_A,HDDM_W
errors = []

for _,group in grouped_with_diff:
    detector = HDDM_A()
    for current, previous in zip(group["difference"], group["difference"].shift(1)):
        detector.add_element(current)
        
        if detector.detected_change() or detector.detected_warning_zone():
            if current > previous and current - previous > 60:
                errors.append(True)
            else:
                errors.append(False)
        else:
            errors.append(False)

more_than_one_site["session_intel_change"] = errors
more_than_one_site.head()
# Out:
#               host       time method  \
# index
# 0      ***.novo.dk  805465029    GET
# 6      ***.novo.dk  805465068    GET
# 12     ***.novo.dk  805465381    GET
# 13     ***.novo.dk  807951768    GET
# 18     ***.novo.dk  807951832    GET
#
#                                                 url  response  bytes  \
# index
# 0                                         /ksc.html       200   7067
# 6                   /shuttle/missions/missions.html       200   8678
# 12        /shuttle/resources/orbiters/columbia.html       200   6922
# 13     /shuttle/missions/sts-69/mission-sts-69.html       200  11264
# 18                              /shuttle/countdown/       200   4673
#
#        difference        average  session_change  session_typical_change  \
# index
# 0             0.0       0.000000           False                   False
# 6            39.0      19.500000            True                   False
# 12          313.0     117.333333            True                    True
# 13      2486387.0  621684.750000            True                    True
# 18           64.0  497360.600000           False                   False
#
#        session_intel_change  correct_session_change
# index
# 0                     False                   False
# 6                      True                   False
# 12                    False                   False
# 13                     True                    True
# 18                    False                   False

# %%
(more_than_one_site["difference"]/more_than_one_site["difference"].max()).head(30).plot()
# more_than_one_site["session_intel_change"].head(30).astype(int).plot()
# more_than_one_site["session_change"].head(30).astype(int).plot()

more_than_one_site["correct_session_change"] = (more_than_one_site["session_intel_change"].apply(int) + more_than_one_site["session_change"].apply(int) ) >1
more_than_one_site["correct_session_change"].head(30).astype(int).plot()
more_than_one_site["session_typical_change"].head(30).astype(int).plot()
# Out:
# <AxesSubplot:xlabel='index'>

# %%
more_than_one_site.head(30)
# Out:
#                                   host       time method  \
# index
# 0                          ***.novo.dk  805465029    GET
# 6                          ***.novo.dk  805465068    GET
# 12                         ***.novo.dk  805465381    GET
# 13                         ***.novo.dk  807951768    GET
# 18                         ***.novo.dk  807951832    GET
# 23                         ***.novo.dk  807951938    GET
# 26                         ***.novo.dk  807952060    GET
# 37                      007.thegap.com  805065755    GET
# 41                      007.thegap.com  805065868    GET
# 44                      007.thegap.com  805066115    GET
# 46                      007.thegap.com  805066664    GET
# 48                      007.thegap.com  805072924    GET
# 52                      007.thegap.com  805073006    GET
# 55                      007.thegap.com  805337998    GET
# 58                      007.thegap.com  805338010    GET
# 61                      007.thegap.com  805338117    GET
# 63                      007.thegap.com  806532047    GET
# 67                      007.thegap.com  807996988    GET
# 71     01-dynamic-c.wokingham.luna.net  804944219    GET
# 74     01-dynamic-c.wokingham.luna.net  805378659    GET
# 80     01-dynamic-c.wokingham.luna.net  805378707    GET
# 83     01-dynamic-c.wokingham.luna.net  805378737    GET
# 85     01-dynamic-c.wokingham.luna.net  805541614    GET
# 90     01-dynamic-c.wokingham.luna.net  806878944    GET
# 96     01-dynamic-c.wokingham.luna.net  806878955    GET
# 99     01-dynamic-c.wokingham.luna.net  809568530    GET
# 102    01-dynamic-c.wokingham.luna.net  809568779    GET
# 104    01-dynamic-c.wokingham.luna.net  809569114    GET
# 105    01-dynamic-c.wokingham.luna.net  809570198    GET
# 111    01-dynamic-c.wokingham.luna.net  809570242    GET
#
#                                                 url  response  bytes  \
# index
# 0                                         /ksc.html       200   7067
# 6                   /shuttle/missions/missions.html       200   8678
# 12        /shuttle/resources/orbiters/columbia.html       200   6922
# 13     /shuttle/missions/sts-69/mission-sts-69.html       200  11264
# 18                              /shuttle/countdown/       200   4673
# 23                  /shuttle/countdown/liftoff.html       200   4665
# 26                   /shuttle/countdown/lps/fr.html       200   1879
# 37                              /shuttle/countdown/       200   3998
# 41     /shuttle/missions/sts-71/mission-sts-71.html       200  12722
# 44     /shuttle/missions/sts-71/mission-sts-71.html       200  12722
# 46      /shuttle/missions/sts-71/images/images.html       200   7634
# 48                              /shuttle/countdown/       200   3998
# 52                     /shuttle/countdown/tour.html       200   4347
# 55                                        /shuttle/       200    957
# 58                               /shuttle/missions/       200  12283
# 61                                                /       200   7067
# 63                              /shuttle/countdown/       200   4324
# 67                              /shuttle/countdown/       200   4673
# 71      /shuttle/missions/sts-71/movies/movies.html       200   3089
# 74                                                /       200   7067
# 80                            /history/history.html       200   1602
# 83                  /shuttle/missions/missions.html       200   8678
# 85     /shuttle/missions/sts-71/mission-sts-71.html       200  13374
# 90                                        /ksc.html       200   7280
# 96                              /shuttle/countdown/       304      0
# 99                /shuttle/countdown/countdown.html       200   4745
# 102                   /shuttle/countdown/count.html       200  73231
# 104                 /shuttle/countdown/liftoff.html       200   6980
# 105                  /shuttle/countdown/lps/fr.html       200   1879
# 111                            /facilities/lcc.html       200   2489
#
#        difference        average  session_change  session_typical_change  \
# index
# 0             0.0       0.000000           False                   False
# 6            39.0      19.500000            True                   False
# 12          313.0     117.333333            True                    True
# 13      2486387.0  621684.750000            True                    True
# 18           64.0  497360.600000           False                   False
# 23          106.0  414484.833333           False                   False
# 26          122.0  355290.142857           False                   False
# 37            0.0       0.000000           False                   False
# 41          113.0      56.500000            True                   False
# 44          247.0     120.000000            True                   False
# 46          549.0     227.250000            True                    True
# 48         6260.0    1433.800000            True                    True
# 52           82.0    1208.500000           False                   False
# 55       264992.0   38891.857143            True                    True
# 58           12.0   34031.875000           False                   False
# 61          107.0   30262.444444           False                   False
# 63      1193930.0  146629.200000            True                    True
# 67      1464941.0  266475.727273            True                    True
# 71            0.0       0.000000           False                   False
# 74       434440.0  217220.000000            True                    True
# 80           48.0  144829.333333           False                   False
# 83           30.0  108629.500000           False                   False
# 85       162877.0  119479.000000            True                    True
# 90      1337330.0  322454.166667            True                    True
# 96           11.0  276390.857143           False                   False
# 99      2689575.0  578038.875000            True                    True
# 102         249.0  513840.000000           False                   False
# 104         335.0  462489.500000           False                    True
# 105        1084.0  420543.545455           False                    True
# 111          44.0  385501.916667           False                   False
#
#        session_intel_change  correct_session_change
# index
# 0                     False                   False
# 6                      True                    True
# 12                    False                   False
# 13                     True                    True
# 18                    False                   False
# 23                     True                   False
# 26                    False                   False
# 37                    False                   False
# 41                     True                    True
# 44                    False                   False
# 46                     True                    True
# 48                    False                   False
# 52                    False                   False
# 55                    False                   False
# 58                    False                   False
# 61                    False                   False
# 63                     True                    True
# 67                    False                   False
# 71                    False                   False
# 74                     True                    True
# 80                    False                   False
# 83                    False                   False
# 85                    False                   False
# 90                     True                    True
# 96                    False                   False
# 99                     True                    True
# 102                   False                   False
# 104                    True                   False
# 105                   False                   False
# 111                   False                   False
